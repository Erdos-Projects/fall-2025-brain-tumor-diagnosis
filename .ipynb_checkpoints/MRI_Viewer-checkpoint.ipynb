# %%
import nibabel as nib
import matplotlib.pylab as plt
import numpy as np
import os

# %%
data_directory = "./data/example/UCSF-PDGM-0004_nifti"
paths = []
for current_dir, inner_dirs, files in os.walk(data_directory):
    for file in files:
        if file.endswith(".nii"):
            file_path = current_dir + "/" + file
            paths.append(file_path.replace("\\","/"))
print(paths)
print(len(paths))
# Out:
# ['./data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_ADC.nii/UCSF-PDGM-0004_ADC.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_ASL.nii/UCSF-PDGM-0004_ASL.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_brain_parenchyma_segmentation.nii/UCSF-PDGM-0004_brain_parenchyma_segmentation.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_brain_segmentation.nii/UCSF-PDGM-0004_brain_segmentation.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_DTI_eddy_FA.nii/UCSF-PDGM-0004_DTI_eddy_FA.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_DTI_eddy_L1.nii/UCSF-PDGM-0004_DTI_eddy_L1.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_DTI_eddy_L2.nii/UCSF-PDGM-0004_DTI_eddy_L2.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_DTI_eddy_L3.nii/UCSF-PDGM-0004_DTI_eddy_L3.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_DTI_eddy_MD.nii/UCSF-PDGM-0004_DTI_eddy_MD.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_DTI_eddy_noreg.nii/UCSF-PDGM-0004_DTI_eddy_noreg.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_DWI.nii/UCSF-PDGM-0004_DWI.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_DWI_bias.nii/UCSF-PDGM-0004_DWI_bias.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_FLAIR.nii/UCSF-PDGM-0004_FLAIR.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_FLAIR_bias.nii/UCSF-PDGM-0004_FLAIR_bias.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_SWI.nii/UCSF-PDGM-0004_SWI.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_SWI_bias.nii/UCSF-PDGM-0004_SWI_bias.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_T1.nii/UCSF-PDGM-0004_T1.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_T1c.nii/UCSF-PDGM-0004_T1c.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_T1c_bias.nii/UCSF-PDGM-0004_T1gad_bias.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_T1_bias.nii/UCSF-PDGM-0004_T1_bias.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_T2.nii/UCSF-PDGM-0004_T2.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_T2_bias.nii/UCSF-PDGM-0004_T2_bias.nii', './data/example/UCSF-PDGM-0004_nifti/UCSF-PDGM-0004_tumor_segmentation.nii/UCSF-PDGM-0004_tumor_segmentation.nii']
# 23

# %%
slice = 120
plt.style.use('default')
fig, axes = plt.subplots(5,5, figsize=(12,12))
for i, ax in enumerate(axes.reshape(-1)):
    if i >= len(paths):
        continue
    file_path = paths[i]
    img = nib.load(file_path).get_fdata()
    if img.shape == (240,240,155):
        ax.imshow(img[:,:, slice])
    ax.set_title(file_path.split("/")[-1], fontsize="small")
fig.tight_layout()
plt.show()

# %%
slice = 150
plt.style.use('default')
fig, axes = plt.subplots(5,5, figsize=(12,12))
for i, ax in enumerate(axes.reshape(-1)):
    if i >= len(paths):
        continue
    file_path = paths[i]
    img = nib.load(file_path).get_fdata()
    if img.shape == (240,240,155):
        ax.imshow(img[:,slice, :])
    ax.set_title(file_path.split("/")[-1], fontsize="small")
fig.tight_layout()
plt.show()

# %%
slice = 161
plt.style.use('default')
fig, axes = plt.subplots(5,5, figsize=(12,12))
for i, ax in enumerate(axes.reshape(-1)):
    if i >= len(paths):
        continue
    file_path = paths[i]
    img = nib.load(file_path).get_fdata()
    if img.shape == (240,240,155):
        ax.imshow(img[slice,:,:])
    ax.set_title(file_path.split("/")[-1], fontsize="small")
fig.tight_layout()
plt.show()

# %%
file_path = paths[0]
starting_slice = 120
print("This is the data from", file_path.split("/")[-1])
img = nib.load(file_path).get_fdata()
print(img.shape)
plt.style.use('default')
fig, axes = plt.subplots(5,5, figsize=(12,12))
for i, ax in enumerate(axes.reshape(-1)):
    ax.imshow(img[:,:, starting_slice + i])
plt.show()
# Out:
# This is the data from UCSF-PDGM-0004_ADC.nii
# (240, 240, 155)
